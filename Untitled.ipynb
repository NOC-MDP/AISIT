# %%
import xarray as xr

# %%
ds = xr.open_dataset("cmems_mod_arc_phy_my_topaz4_P1M_stfbaro_180.00W-179.88E_50.00N-90.00N_1991-01-01-2025-10-01.nc")

point1 = ds.sel("latitude" == 80,"longitude"==100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 ds = xr.open_dataset("cmems_mod_arc_phy_my_topaz4_P1M_stfbaro_180.00W-179.88E_50.00N-90.00N_1991-01-01-2025-10-01.nc")
# ----> 3 point1 = ds.sel("latitude" == 80,"longitude"==100)
#
# File ~/miniforge3/envs/AISIT/lib/python3.12/site-packages/xarray/core/dataset.py:2987, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2912 def sel(
#    2913     self,
#    2914     indexers: Mapping[Any, Any] | None = None,
#    (...)   2918     **indexers_kwargs: Any,
#    2919 ) -> Self:
#    2920     """Returns a new dataset with each array indexed by tick labels
#    2921     along the specified dimension(s).
#    2922
#    (...)   2985
#    2986     """
# -> 2987     indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
#    2988     query_results = map_index_queries(
# ...
