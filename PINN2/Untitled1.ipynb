# %%
import xarray as xr 

ds = xr.open_dataset("/gws/ssde/j25a/nemo/vol4/thopri/PINN/infer_output/eORCA12_tracer_predictions_master.nc")
print(ds)

ds["tracer_pred"].mean(dim='time_counter').plot(cmap='RdBu_r')
# Out:
# <xarray.Dataset> Size: 37GB
# Dimensions:             (time_counter: 12, deptht: 75, y: 693, x: 3665)
# Coordinates:
#   * time_counter        (time_counter) datetime64[ns] 96B 1976-01-16T12:00:00...
#   * deptht              (deptht) float32 300B 0.5058 1.556 ... 5.902e+03
#   * y                   (y) int64 6kB 2912 2913 2914 2915 ... 3602 3603 3604
#   * x                   (x) int64 29kB 328 329 330 331 ... 3989 3990 3991 3992
#     nav_lon             (y, x) float64 20MB ...
#     nav_lat             (y, x) float64 20MB ...
#     time_centered       datetime64[ns] 8B ...
# Data variables:
#     tracer_pred         (time_counter, deptht, y, x) float64 18GB ...
#     tracer_uncertainty  (time_counter, deptht, y, x) float64 18GB ...
# Attributes: (12/32)
#     name:                        OUTPUT/eORCA12_1m_grid_T
#     description:                 NOC Near-Present Day monthly mean global oce...
#     title:                       National Oceanography Centre Near-Present Da...
# ...
